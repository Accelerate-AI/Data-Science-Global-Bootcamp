# %% [markdown]
# ## AccelerateAI Data Science Global Bootcamp
#
# ### Model Selection Methods
#
# We will look at the following methods to select the value of alpha for LASSO regresion
#  - AIC
#  - BIC
#  - Cross Validation

# %%
# Required libraries for model selection
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoLarsIC             #Lasso model fit using BIC or AIC for model selection.
from sklearn.pipeline import make_pipeline

# %%
from sklearn.datasets import load_diabetes

# Load the diabetes dataset
X, y = load_diabetes(return_X_y=True, as_frame=True)
X.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
y.head()
# Out:
# 0    151.0
# 1     75.0
# 2    141.0
# 3    206.0
# 4    135.0
# Name: target, dtype: float64

# %%
# Add few random features as well  
rng = np.random.RandomState(2021)
n_random_features = 10
X_random = pd.DataFrame( rng.randn(X.shape[0], n_random_features),
                         columns=[f"r{i}" for i in range(n_random_features)],
                       )
X = pd.concat([X, X_random], axis=1)
# Show only a subset of the columns
X.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6        r0        r1        r2        r3  \
# 0 -0.002592  0.019908 -0.017646  1.488609  0.676011 -0.418451 -0.806521
# 1 -0.039493 -0.068330 -0.092204  0.124207 -0.837953  0.409016  0.102751
# 2 -0.002592  0.002864 -0.025930 -0.720159  2.544915  1.317291  0.072630
# 3  0.034309  0.022692 -0.009362  1.485108  1.482432  0.728131 -0.389648
# 4 -0.002592 -0.031991 -0.046641  0.240108  0.477812  0.208852  0.917912
#
#          r4        r5        r6        r7        r8        r9
# 0  0.555876 -0.705504  1.130858  0.645002  0.106414  0.422155
# 1 -1.907722  1.100224 -1.402325 -0.225081 -1.336206  0.303722
# 2 -0.256108  0.138010  1.147236  1.376261 -0.472184  0.524085
# 3  0.278894  0.051900 -1.044744 -0.161508 -2.793531  0.361648
# 4 -1.411778  1.224236 -0.545658  0.906748 -0.982617 -0.633162

# %%
lasso_ic = make_pipeline(StandardScaler(), 
                              LassoLarsIC(criterion="aic", normalize=False)
                             ).fit(X, y)

# %%
# Store the AIC metric for each value of alpha used during fit.
results = pd.DataFrame(
    {
        "alphas": lasso_ic[-1].alphas_,
        "AIC criterion": lasso_ic[-1].criterion_,
    }
).set_index("alphas")
alpha_aic = lasso_ic[-1].alpha_

# %%
# Model coefficients with AIC 
list(zip(X.columns, lasso_ic[-1].coef_))
# Out:
# [('age', 0.0),
#  ('sex', -9.758922885057379),
#  ('bmi', 25.2951042901323),
#  ('bp', 13.996381369711937),
#  ('s1', -4.507930670370241),
#  ('s2', 0.0),
#  ('s3', -10.281899442391454),
#  ('s4', 0.0),
#  ('s5', 24.33241009488148),
#  ('s6', 3.5260874930876103),
#  ('r0', -2.5724988331272103),
#  ('r1', -3.751921833009503),
#  ('r2', 0.0),
#  ('r3', -0.7530297805111872),
#  ('r4', 0.0),
#  ('r5', -2.228655436183959),
#  ('r6', -3.1531438055208008),
#  ('r7', 2.1293949964865106),
#  ('r8', -1.0203880701439172),
#  ('r9', -2.120271508629494)]

# %%
# Perform the same analysis using the BIC criterion.
lasso_bic = lasso_ic.set_params(lassolarsic__criterion="bic").fit(X, y)

# Append the results in the same dataframe
results["BIC criterion"] = lasso_ic[-1].criterion_
alpha_bic = lasso_ic[-1].alpha_

# %%
# Model coefficients with BIC 
list(zip(X.columns, lasso_ic[-1].coef_))
# Out:
# [('age', 0.0),
#  ('sex', -3.431182149852974),
#  ('bmi', 24.312306753262586),
#  ('bp', 11.061904669850477),
#  ('s1', 0.0),
#  ('s2', 0.0),
#  ('s3', -7.974191414317996),
#  ('s4', 0.0),
#  ('s5', 21.416644296316978),
#  ('s6', 0.0),
#  ('r0', 0.0),
#  ('r1', 0.0),
#  ('r2', 0.0),
#  ('r3', 0.0),
#  ('r4', 0.0),
#  ('r5', 0.0),
#  ('r6', 0.0),
#  ('r7', 0.0),
#  ('r8', 0.0),
#  ('r9', 0.0)]

# %%
# Compare the AIC and BIC values
results.style.highlight_min().format("{:.2f}")
# Out:
# <style type="text/css">
# #T_53010_row5_col1, #T_53010_row17_col0 {
#   background-color: yellow;
# }
# </style>
# <table id="T_53010">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53010_level0_col0" class="col_heading level0 col0" >AIC criterion</th>
#       <th id="T_53010_level0_col1" class="col_heading level0 col1" >BIC criterion</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >alphas</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53010_level0_row0" class="row_heading level0 row0" >45.160030</th>
#       <td id="T_53010_row0_col0" class="data row0 col0" >5237.11</td>
#       <td id="T_53010_row0_col1" class="data row0 col1" >5237.11</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row1" class="row_heading level0 row1" >42.300448</th>
#       <td id="T_53010_row1_col0" class="data row1 col0" >5201.23</td>
#       <td id="T_53010_row1_col1" class="data row1 col1" >5205.32</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row2" class="row_heading level0 row2" >21.542302</th>
#       <td id="T_53010_row2_col0" class="data row2 col0" >4925.62</td>
#       <td id="T_53010_row2_col1" class="data row2 col1" >4933.80</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row3" class="row_heading level0 row3" >15.034110</th>
#       <td id="T_53010_row3_col0" class="data row3 col0" >4868.26</td>
#       <td id="T_53010_row3_col1" class="data row3 col1" >4880.54</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row4" class="row_heading level0 row4" >6.189693</th>
#       <td id="T_53010_row4_col0" class="data row4 col0" >4814.94</td>
#       <td id="T_53010_row4_col1" class="data row4 col1" >4831.31</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row5" class="row_heading level0 row5" >4.295932</th>
#       <td id="T_53010_row5_col0" class="data row5 col0" >4803.12</td>
#       <td id="T_53010_row5_col1" class="data row5 col1" >4823.57</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row6" class="row_heading level0 row6" >4.231800</th>
#       <td id="T_53010_row6_col0" class="data row6 col0" >4804.64</td>
#       <td id="T_53010_row6_col1" class="data row6 col1" >4829.19</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row7" class="row_heading level0 row7" >3.649706</th>
#       <td id="T_53010_row7_col0" class="data row7 col0" >4802.41</td>
#       <td id="T_53010_row7_col1" class="data row7 col1" >4831.05</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row8" class="row_heading level0 row8" >3.565477</th>
#       <td id="T_53010_row8_col0" class="data row8 col0" >4803.75</td>
#       <td id="T_53010_row8_col1" class="data row8 col1" >4836.48</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row9" class="row_heading level0 row9" >3.262927</th>
#       <td id="T_53010_row9_col0" class="data row9 col0" >4803.12</td>
#       <td id="T_53010_row9_col1" class="data row9 col1" >4839.94</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row10" class="row_heading level0 row10" >3.254101</th>
#       <td id="T_53010_row10_col0" class="data row10 col0" >4805.03</td>
#       <td id="T_53010_row10_col1" class="data row10 col1" >4845.94</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row11" class="row_heading level0 row11" >3.251646</th>
#       <td id="T_53010_row11_col0" class="data row11 col0" >4805.00</td>
#       <td id="T_53010_row11_col1" class="data row11 col1" >4845.91</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row12" class="row_heading level0 row12" >2.927600</th>
#       <td id="T_53010_row12_col0" class="data row12 col0" >4801.62</td>
#       <td id="T_53010_row12_col1" class="data row12 col1" >4842.54</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row13" class="row_heading level0 row13" >2.790436</th>
#       <td id="T_53010_row13_col0" class="data row13 col0" >4802.17</td>
#       <td id="T_53010_row13_col1" class="data row13 col1" >4847.17</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row14" class="row_heading level0 row14" >2.727295</th>
#       <td id="T_53010_row14_col0" class="data row14 col0" >4803.47</td>
#       <td id="T_53010_row14_col1" class="data row14 col1" >4852.56</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row15" class="row_heading level0 row15" >2.169520</th>
#       <td id="T_53010_row15_col0" class="data row15 col0" >4799.40</td>
#       <td id="T_53010_row15_col1" class="data row15 col1" >4852.59</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row16" class="row_heading level0 row16" >1.658158</th>
#       <td id="T_53010_row16_col0" class="data row16 col0" >4796.88</td>
#       <td id="T_53010_row16_col1" class="data row16 col1" >4854.16</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row17" class="row_heading level0 row17" >0.922782</th>
#       <td id="T_53010_row17_col0" class="data row17 col0" >4794.21</td>
#       <td id="T_53010_row17_col1" class="data row17 col1" >4855.58</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row18" class="row_heading level0 row18" >0.751513</th>
#       <td id="T_53010_row18_col0" class="data row18 col0" >4795.23</td>
#       <td id="T_53010_row18_col1" class="data row18 col1" >4860.69</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row19" class="row_heading level0 row19" >0.710754</th>
#       <td id="T_53010_row19_col0" class="data row19 col0" >4797.02</td>
#       <td id="T_53010_row19_col1" class="data row19 col1" >4866.57</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row20" class="row_heading level0 row20" >0.204988</th>
#       <td id="T_53010_row20_col0" class="data row20 col0" >4797.28</td>
#       <td id="T_53010_row20_col1" class="data row20 col1" >4870.93</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row21" class="row_heading level0 row21" >0.171205</th>
#       <td id="T_53010_row21_col0" class="data row21 col0" >4798.88</td>
#       <td id="T_53010_row21_col1" class="data row21 col1" >4876.61</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row22" class="row_heading level0 row22" >0.063292</th>
#       <td id="T_53010_row22_col0" class="data row22 col0" >4798.05</td>
#       <td id="T_53010_row22_col1" class="data row22 col1" >4875.79</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row23" class="row_heading level0 row23" >0.037792</th>
#       <td id="T_53010_row23_col0" class="data row23 col0" >4798.02</td>
#       <td id="T_53010_row23_col1" class="data row23 col1" >4875.76</td>
#     </tr>
#     <tr>
#       <th id="T_53010_level0_row24" class="row_heading level0 row24" >0.000000</th>
#       <td id="T_53010_row24_col0" class="data row24 col0" >4799.92</td>
#       <td id="T_53010_row24_col1" class="data row24 col1" >4881.75</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Check this for more styling help: https://pandas.pydata.org/docs/user_guide/style.html

# %%
from sklearn.linear_model import LassoCV

lasso_cv = make_pipeline(StandardScaler(), LassoCV(cv=20)).fit(X, y)

list(zip(X.columns, lasso_cv[-1].coef_))
# Out:
# [('age', -0.0),
#  ('sex', -9.536996678241735),
#  ('bmi', 25.256439950451337),
#  ('bp', 13.889188432092507),
#  ('s1', -4.284857841530376),
#  ('s2', -0.0),
#  ('s3', -10.233736588336283),
#  ('s4', 0.0),
#  ('s5', 24.17423864547707),
#  ('s6', 3.379955481287983),
#  ('r0', -2.4587873275084653),
#  ('r1', -3.622093300367794),
#  ('r2', 0.0),
#  ('r3', -0.6296500863571339),
#  ('r4', -0.0),
#  ('r5', -2.103889811312806),
#  ('r6', -3.0112058597713647),
#  ('r7', 1.987414914073564),
#  ('r8', -0.9183424183510114),
#  ('r9', -1.982232287027096)]

# %%
print(f'Best alpha from CV: {lasso_cv[-1].alpha_}')
# Out:
# Best alpha from CV: 1.0432552660691845

# %% [markdown]
# ***
