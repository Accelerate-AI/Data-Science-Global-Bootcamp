# %% [markdown]
# # AccelerateAI - Data Science Bootcamp

# %% [markdown]
# ## Python Libraries for Data Visualization

# %% [markdown]
# ![DV_Libraries](./PythonLibraries_DV.jpg)

# %% [markdown]
# ## Data Visualization using Seaborn

# %% [markdown]
# - Seaborn is a high level package
# - As the charts get more complex, the more the code you’ve got to write if we use libraries such as matplotlib. For example, in matplotlib, there is no direct method to draw a density plot of a scatterplot with line of best fit. So, we use a higher level package like seaborn, and use one of its prebuilt functions to draw the plot.
# - A lot of seaborn’s plots are suitable for data analysis and the library works seamlessly with pandas dataframes.
# - Seaborn is typically imported as sns. Like matplotlib it comes with its own set of pre-built styles and palettes.
# - Seaborn Plotting Organization can be looked like the following:
#
# ![Seaborn Plot Org](./Seaborn_Plot_Organization.png)

# %% [markdown]
# ## API Overview

# %% [markdown]
# You could observe from the above pictorial representation - relational, distributions and categorical.
#
# * Relational plots:
#     * relplot: Figure-level interface for drawing relational plots onto a FacetGrid
#     * scatterplot: Draw a scatter plot with possibility of several semantic groupings
#     * lineplot: Draw a line plot with possibility of several semantic groupings
# * Distribution plots: The distributions module defines functions that specialize in representing the distribution of datapoints.
#     * displot: Figure-level interface for drawing distribution plots onto a FacetGrid
#     * histplot: Plot univariate or bivariate histograms to show distributions of datasets
#     * kdeplot: Plot univariate or bivariate distributions using kernel density estimation
#     * ecdfplot: Plot empirical cumulative distribution functions
#     * rugplot: Plot marginal distributions by drawing ticks along the x and y axes
# * Categorical plots:
#     * catplot: Figure-level interface for drawing categorical plots onto a FacetGrid
#     * stripplot: Draw a scatterplot where one variable is categorical
#     * swarmplot: Draw a categorical scatterplot with non-overlapping points
#     * boxplot: Draw a box plot to show distributions with respect to categories
#     * violinplot: Draw a combination of boxplot and kernel density estimate
#     * pointplot: Show point estimates and confidence intervals using scatter plot glyphs
#     * barplot: Show point estimates and confidence intervals as rectangular bars

# %% [markdown]
# There are also other type of plots. Some of them are captured below.
# * Regression Plots
#     * lmplot: Plot data and regression model fits across a FacetGrid
#     * regplot: Plot data and a linear regression model fit
#     * residplot: Plot the residuals of a linear regression
# * Matrix plots
#     * heatmap: Plot rectangular data as a color-encoded matrix
#     * clustermap: Plot a matrix dataset as a hierarchically-clustered heatmap

# %% [markdown]
# ## 1. Import Packages and Basic Plotting

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import seaborn as sns

# A jupyter notebook specific command that let’s you see the plots in the notbook itself.
# %matplotlib inline 

import warnings
warnings.filterwarnings('ignore')

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
# We consider the car_crashes data set which is divided into different states in the U.S. 
# Each state has different features.Ignoring the ‘abbrev’ feature which just tells us the state, we can use this data set to predict almost any feature.

car_crashes = sns.load_dataset('car_crashes')

car_crashes.sample(8)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 43   19.4     7.760    7.372          17.654       16.878      1004.75
# 37   12.8     4.224    3.328           8.576       11.520       804.71
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 39   11.1     3.774    4.218          10.212        8.769      1148.99
# 14   14.5     3.625    4.205          13.775       13.775       710.46
# 21    8.2     1.886    2.870           7.134        6.560      1011.14
# 3    22.4     4.032    5.824          21.056       21.280       827.34
#
#     ins_losses abbrev
# 4       165.63     CA
# 43      156.83     TX
# 37      104.61     OR
# 0       145.08     AL
# 39      148.58     RI
# 14      108.92     IN
# 21      135.63     MA
# 3       142.39     AR

# %% [markdown]
# * total -> Number of drivers involved in fatal collisions per billion miles (5.900–23.900)
# * speeding -> Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding (1.792–9.450)
# * alcohol -> Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired (1.593–10.038)
# * not_distracted -> Percentage Of Drivers Involved In Fatal Collisions Who Were Not Distracted (1.760–23.661)
# * no_previous -> Percentage Of Drivers Involved In Fatal Collisions Who Had Not Been Involved In Any Previous Accidents (5.900–21.280)
# * ins_premium -> Car Insurance Premiums (641.960–1301.520)
# * ins_losses -> Losses incurred by insurance companies for collisions per insured driver (82.75–194.780)
# * abbrev -> USA states

# %% [markdown]
# ## 2. Relational Plots (```relplot```) in Seaborn

# %% [markdown]
# **Relational Plotting**
# - relplot
# - scatterplot
# - lineplot
#
# ```seaborn.relplot```(\*, x=None, y=None, hue=None, size=None, style=None, data=None, row=None, col=None, col_wrap=None, row_order=None, col_order=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=None, dashes=None, style_order=None, legend='auto', kind='scatter', height=5, aspect=1, facet_kws=None, units=None, **kwargs)

# %%
sns.relplot(data=car_crashes, x="speeding", y="alcohol") # default kind is scatterplot
plt.show()

# %%
sns.relplot(data=car_crashes, x="no_previous", y="ins_losses") # default kind is scatterplot
plt.show()

# %%
sns.relplot(data=car_crashes, x="no_previous", y="ins_losses",  kind="line") # change the kind-specific options
plt.show()

# %%
# We can consider the tips dataset
tips = sns.load_dataset("tips")
tips.sample(8)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 57        26.41  1.50  Female     No   Sat  Dinner     2
# 55        19.49  3.51    Male     No   Sun  Dinner     2
# 150       14.07  2.50    Male     No   Sun  Dinner     2
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2
# 137       14.15  2.00  Female     No  Thur   Lunch     2
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2
# 140       17.47  3.50  Female     No  Thur   Lunch     2
# 81        16.66  3.40    Male     No  Thur   Lunch     2

# %%
# Add a semantic variable / grouping variable as hue in addition to x and y variables

sns.relplot(data=tips, x="total_bill", y="tip", hue="day")
plt.show()

# %% [markdown]
# Assigning a col variable creates a faceted figure with multiple subplots arranged across the columns of the grid

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="day", col="time")
plt.show()

# %% [markdown]
# Different variables can be assigned to facet on both the columns and rows:

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="day", col="time", row="sex")
plt.show()

# %% [markdown]
# When the variable assigned to col has many levels, it can be “wrapped” across multiple rows

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="time", col="day", col_wrap=2)
plt.show()

# %% [markdown]
# Assigning multiple semantic variables can show multi-dimensional relationships, but be mindful to avoid making an overly-complicated plot

# %%
sns.relplot(
    data=tips, x="total_bill", y="tip", col="time",
    hue="time", size="size", style="sex",
    palette=["b", "r"], sizes=(10, 100)
)
plt.show()

# %% [markdown]
# When there is a natural continuity to one of the variables, it makes more sense to show lines instead of points. To draw the figure using lineplot(), set kind="line". We will illustrate this effect with the “fmri" dataset.
#
# * FMRI: Functional Magnetic Resonance Imaging or functional MRI (fMRI)
# * It measures brain activity using a strong, static magnetic field to detect changes associated with blood flow. When an area of the brain is in use, blood flow to that region also increases.

# %%
fmri = sns.load_dataset("fmri")
fmri.sample(6)
# Out:
#     subject  timepoint event    region    signal
# 363      s0          7  stim   frontal  0.007993
# 197     s13          4  stim  parietal  0.136219
# 945      s6         11   cue   frontal -0.052012
# 758      s4          9   cue  parietal -0.149299
# 76       s8         13  stim  parietal -0.123950
# 960     s13         13   cue   frontal -0.009388

# %% [markdown]
# Using kind="line" offers the same flexibility for semantic mappings as kind="scatter", but lineplot() transforms the data more before plotting. Observations are sorted by their x value, and repeated observations are aggregated. By default, the resulting plot shows the mean and 95% CI for each unit

# %%
sns.relplot(
    data=fmri, x="timepoint", y="signal", col="region",
    hue="event", style="event", kind="line",
)
plt.show()

# %% [markdown]
# We can also use relplot() to use wide-form of data. Faceting is not an option in this case, but the plot will still take advantage of the external legend offered by FacetGrid.

# %%
flights_pivot = sns.load_dataset("flights").pivot("year", "month", "passengers")

# %%
flights_pivot.sample(4)
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.relplot(data=flights_pivot, kind="line", height=6)

plt.show()

# %% [markdown]
# ## 3. Distribution Plots (```displot```) in Seaborn

# %% [markdown]
# **Distribution Plots**
#
# - displot
# - histplot : univariate / bivariate histograms
# - kdeplot : Kernel Density Estimation for plotting univariate / bivariate distributions
# - ecdfplot: Empirical Cumulative Distribution Function plots
# - rugplot : Marginal distributions

# %% [markdown]
# ### 3a) displot - default is a Histogram

# %%
penguins = sns.load_dataset("penguins")

penguins.sample(4)
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 314     Gentoo  Biscoe            44.5           14.7              214.0
# 234     Gentoo  Biscoe            45.8           14.6              210.0
# 216  Chinstrap   Dream            43.5           18.1              202.0
# 331     Gentoo  Biscoe            49.8           15.9              229.0
#
#      body_mass_g     sex
# 314       4850.0  Female
# 234       4200.0  Female
# 216       3400.0  Female
# 331       5950.0    Male

# %%
sns.displot(data=penguins, x="flipper_length_mm")  # default is histogram

plt.show()

# %%
sns.displot(data=penguins, x="flipper_length_mm", kind="kde")

plt.show()

# %%
sns.displot(data=penguins, x="flipper_length_mm", kind="ecdf")

plt.show()

# %% [markdown]
# We can include KDE to the default Histogram as well.

# %%
sns.displot(data=penguins, x="flipper_length_mm", kde=True)

plt.show()

# %%
penguins.sample(4)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 18   Adelie  Torgersen            34.4           18.4              184.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 232  Gentoo     Biscoe            45.5           13.7              214.0
#
#      body_mass_g     sex
# 18        3325.0  Female
# 9         4250.0     NaN
# 148       3450.0  Female
# 232       4650.0  Female

# %%
sns.distplot(penguins['flipper_length_mm'])

plt.show()

# %% [markdown]
# We can also draw bivariate plots.

# %%
penguins.sample(4)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 33   Adelie   Dream            40.9           18.9              184.0
# 142  Adelie   Dream            32.1           15.5              188.0
# 22   Adelie  Biscoe            35.9           19.2              189.0
# 260  Gentoo  Biscoe            42.7           13.7              208.0
#
#      body_mass_g     sex
# 33        3900.0    Male
# 142       3050.0  Female
# 22        3800.0  Female
# 260       3950.0  Female

# %%
sns.displot(data=penguins, x="flipper_length_mm", y="bill_length_mm")

plt.show()

# %% [markdown]
#  Bivariate plots are available only for Histograms and KDEs.

# %%
sns.displot(data=penguins, x="flipper_length_mm", y="bill_length_mm", kind="kde")

plt.show()

# %% [markdown]
# Each kind of plot can be drawn separately for subsets of data using ```hue``` mapping.

# %%
penguins.sample(4)
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 65      Adelie  Biscoe            41.6           18.0              192.0
# 200  Chinstrap   Dream            51.5           18.7              187.0
# 40      Adelie   Dream            36.5           18.0              182.0
# 296     Gentoo  Biscoe            47.5           14.2              209.0
#
#      body_mass_g     sex
# 65        3950.0    Male
# 200       3250.0    Male
# 40        3150.0  Female
# 296       4600.0  Female

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", kind="kde")

plt.show()

# %% [markdown]
# Stacked Histogram

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

plt.show()

# %% [markdown]
# ### 3b) histplot

# %%
penguins = sns.load_dataset("penguins")

penguins.sample(4)
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 87      Adelie   Dream            36.9           18.6              189.0
# 274     Gentoo  Biscoe            46.5           14.4              217.0
# 214  Chinstrap   Dream            45.7           17.0              195.0
# 28      Adelie  Biscoe            37.9           18.6              172.0
#
#      body_mass_g     sex
# 87        3500.0  Female
# 274       4900.0  Female
# 214       3650.0  Female
# 28        3150.0  Female

# %% [markdown]
# If neither x nor y is assigned, the dataset is treated as wide-form, and a histogram is drawn for each numeric column.

# %%
sns.histplot(data=penguins)

plt.show()

# %%
# Univariate - vertical representation of histogram

sns.histplot(data=penguins, x="flipper_length_mm")

plt.show()

# %% [markdown]
# Univariate - if you want to display horizontally in y axis

# %%
sns.histplot(data=penguins, y="flipper_length_mm")

plt.show()

# %% [markdown]
# Check how well the histogram represents the data by specifying a different bin width.

# %%
sns.histplot(data=penguins, x="flipper_length_mm", binwidth=2)

plt.show()

# %% [markdown]
# The default approach to plotting multiple distributions is to “layer” them, but you can also “stack” them.

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

plt.show()

# %% [markdown]
# Overlapping bars can be hard to visually resolve. A different approach would be to draw a step function.

# %%
sns.histplot(penguins, x="flipper_length_mm", hue="species", element="step")

plt.show()

# %% [markdown]
# It’s also possible to normalize so that each bar’s height shows a probability, proportion, or percent, which make more sense for discrete variables.

# %%
tips = sns.load_dataset("tips")
sns.histplot(data=tips, x="size", stat="probability", discrete=True)

plt.show()

# %% [markdown]
# You can even draw a histogram over categorical variables.

# %%
sns.histplot(data=tips, x="day", shrink=0.9)

plt.show()

# %% [markdown]
# When using a ```hue``` semantic with discrete data, it can make sense to “dodge” the levels.

# %%
sns.histplot(data=tips, x="day", hue="sex", multiple="dodge", shrink=.9)

plt.show()

# %% [markdown]
# Real-world data is often skewed. For heavily skewed distributions, it’s better to define the bins in log space.
#
# Hence, for the following data:

# %%
planets = sns.load_dataset("planets")
sns.histplot(data=planets, x="distance")

plt.show()

# %% [markdown]
# We can convert to a Log Scale:

# %%
sns.histplot(data=planets, x="distance", log_scale=True)

plt.show()

# %% [markdown]
# ### 3c) kdeplot

# %%
tips = sns.load_dataset("tips")

tips.sample(4)
# Out:
#     total_bill   tip   sex smoker   day    time  size
# 28       21.70  4.30  Male     No   Sat  Dinner     2
# 26       13.37  2.00  Male     No   Sat  Dinner     2
# 1        10.34  1.66  Male     No   Sun  Dinner     3
# 78       22.76  3.00  Male     No  Thur   Lunch     2

# %% [markdown]
# We can leverage ```kdeplot``` to plot density.

# %%
# A simple univariate distribution along x-axis

sns.kdeplot(data=tips, x="total_bill")

plt.show()

# %%
# We can also represent in y-axis

sns.kdeplot(data=tips, y="total_bill")

plt.show()

# %%
# Plot distribution in a wide-form dataset

tips = sns.load_dataset("tips")
sns.kdeplot(data=tips)

plt.show()

# %%
# We can use less smoothing

sns.kdeplot(data=tips, x="total_bill", bw_adjust=1.5)

plt.show()

# %%
# We can plot conditional distributions with hue mapping

sns.kdeplot(data=tips, x="total_bill", hue="time")

plt.show()

# %%
# We can stack conditional distributions

sns.kdeplot(data=tips, x="total_bill", hue="time", multiple="stack")
plt.show()

# %%
# Normalize the stacked distribution

sns.kdeplot(data=tips, x="total_bill", hue="time", multiple="fill")
plt.show()

# %% [markdown]
# Log Scaling - We will see how this is used.

# %%
diamonds = sns.load_dataset("diamonds")

diamonds.sample(4)
# Out:
#        carat    cut color clarity  depth  table  price     x     y     z
# 25068   1.06  Ideal     D    VVS2   61.9   56.0  13588  6.51  6.54  4.04
# 37270   0.26  Ideal     H     VS1   62.2   55.0    482  4.12  4.14  2.57
# 29591   0.32  Ideal     D     SI1   62.9   56.0    706  4.40  4.38  2.76
# 12678   1.01  Ideal     H     VS2   62.7   57.0   5306  6.41  6.39  4.01

# %%
# Map variables when log scaling is not yet applied

sns.kdeplot(data=diamonds, x="price")
plt.show()

# %%
# Map variables with log scaling is applied

diamonds = sns.load_dataset("diamonds")
sns.kdeplot(data=diamonds, x="price", log_scale=True)
plt.show()

# %% [markdown]
# Numeric Hue Mapping:

# %%
sns.kdeplot(data=tips, x="total_bill", hue="size")
plt.show()

# %% [markdown]
# Modify the appearance of the plot:

# %%
sns.kdeplot(
   data=tips, x="total_bill", hue="size",
   fill=True, common_norm=False, palette="crest",
   alpha=0.45, linewidth=0
)
plt.show()

# %% [markdown]
# Bivariate Distribution:

# %%
geyser = sns.load_dataset("geyser")

geyser.sample(4)
# Out:
#      duration  waiting   kind
# 151     4.000       77   long
# 159     3.967       89   long
# 236     1.850       54  short
# 45      3.317       83   long

# %%
sns.kdeplot(data=geyser, x="waiting", y="duration")
plt.show()

# %% [markdown]
# We can map a third variable with a hue semantic to show conditional distributions:

# %%
sns.kdeplot(data=geyser, x="waiting", y="duration", hue="kind")

plt.show()

# %%
# Import Data
df = pd.read_csv("C:/Users/mishr/Desktop/Notebooks/data/mpg_ggplot2.csv") 

df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %% [markdown]
# This is MPG dataset from ggplot2 package.
#
# - Manufacturer of the vehicle
# - Model of the vehicle
# - Displacement or engine size of vehicle in litres
# - Model year of the vehicle
# - No of cylinders
# - Type of transmissions
# - Drivetrain: Forward, rear, 4-wheel etc
# - The number of city miles per gallon that the car is able to achieve
# - The number of highway miles per gallon that the car is able to achieve
# - Fuel type
# - Class of vehicle: Compact, Subcompact, Midsize etc

# %%
sns.set_style("white")

# Draw Plot
plt.figure(figsize=(7,4), dpi= 80)
sns.kdeplot(df.loc[df['cyl'] == 4, "cty"], shade=True, color="g", label="Cyl=4", alpha=.7)
sns.kdeplot(df.loc[df['cyl'] == 6, "cty"], shade=True, color="dodgerblue", label="Cyl=6", alpha=.7)
sns.kdeplot(df.loc[df['cyl'] == 8, "cty"], shade=True, color="orange", label="Cyl=8", alpha=.7)

# Decoration
plt.title('Sample representation of Density Plot', fontsize=12)
plt.ylabel("Density")
plt.xlabel("cty")
plt.legend()
plt.show()

# %% [markdown]
# ## 4. Categorical Plots (```catplot```) in Seaborn

# %% [markdown]
# **Categorical Plots**
#
# - Default representation onto a FacetGrid:
#     - catplot()
# - Categorical Scatterplots:
#     - stripplot()
#     - swarmplot()
# - Categorical Distribution Plots:
#     - boxplot()
#     - violinplot()
#     - boxenplot()
# - Categorical Estimation Plots:
#     - pointplot()
#     - barplot()
#     - countplot()

# %% [markdown]
# ### 4a) catplot, stripplot and swarmplot

# %%
tips = sns.load_dataset("tips")
sns.catplot(x="day", y="total_bill", data=tips)

plt.show()

# %% [markdown]
# The jitter parameter controls the magnitude of jitter or disables it altogether.

# %%
sns.catplot(x="day", y="total_bill", jitter=False, data=tips)

plt.show()

# %% [markdown]
# The second approach adjusts the points along the categorical axis using an algorithm that prevents them from overlapping. It can give a better representation of the distribution of observations, although it only works well for relatively small datasets. This kind of plot is sometimes called a “beeswarm” and is drawn in seaborn by swarmplot(), which is activated by setting kind="swarm" in catplot().

# %%
sns.catplot(x="day", y="total_bill", kind="swarm", data=tips)

plt.show()

# %% [markdown]
# Similar to the relational plots, it’s possible to add another dimension to a categorical plot by using a hue semantic. (The categorical plots do not currently support size or style semantics). Each different categorical plotting function handles the hue semantic differently. For the scatter plots, it is only necessary to change the color of the points

# %%
sns.catplot(x="day", y="total_bill", hue="sex", kind="swarm", data=tips)

plt.show()

# %% [markdown]
# #### Distributions of observations within categories

# %% [markdown]
# As the size of the dataset grows, categorical scatter plots become limited in the information they can provide about the distribution of values within each category. When this happens, there are several approaches for summarizing the distributional information in ways that facilitate easy comparisons across the category levels

# %% [markdown]
# ### 4b) Boxplot, Violinplot and Boxenplot

# %% [markdown]
# **Boxplot()** is kind of plot shows the three quartile values of the distribution along with extreme values. The “whiskers” extend to points that lie within 1.5 IQRs of the lower and upper quartile, and then observations that fall outside this range are displayed independently. This means that each value in the boxplot corresponds to an actual observation in the data.

# %%
sns.catplot(x="day", y="total_bill", kind="box", data=tips)

plt.show()

# %% [markdown]
# When adding a hue semantic, the box for each level of the semantic variable is moved along the categorical axis so they don’t overlap:

# %%
sns.catplot(x="day", y="total_bill", hue="sex", kind="box", data=tips)
plt.show()

# %% [markdown]
# This behavior is called “dodging” and is turned on by default because it is assumed that the semantic variable is nested within the main categorical variable. If that’s not the case, you can disable the dodging:

# %%
tips["weekend"] = tips["day"].isin(["Sat", "Sun"])
sns.catplot(x="day", y="total_bill", hue="weekend",
            kind="box", dodge=False, data=tips)
plt.show()

# %% [markdown]
# A related function, boxenplot(), draws a plot that is similar to a box plot but optimized for showing more information about the shape of the distribution. It is best suited for larger datasets:

# %%
diamonds = sns.load_dataset("diamonds")

diamonds.sample(4)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 21784   2.02  Very Good     G     SI2   63.3   57.0   9853  8.03  7.96  5.06
# 32890   0.36    Premium     E     SI1   61.3   56.0    810  4.62  4.58  2.82
# 43929   0.30      Ideal     I    VVS2   62.6   56.0    515  4.26  4.30  2.68
# 43578   0.41    Premium     E    VVS1   62.2   58.0   1431  4.77  4.75  2.96

# %%
sns.catplot(x="color", y="price", kind="boxen",
            data=diamonds.sort_values("color"))

plt.show()

# %% [markdown]
# **Violin Plots**

# %% [markdown]
# A violinplot() combines a boxplot with the kernel density estimation procedure.

# %%
sns.catplot(x="total_bill", y="day", hue="sex",
            kind="violin", data=tips)

plt.show()

# %% [markdown]
# - This approach uses the kernel density estimate to provide a richer description of the distribution of values.
# - Additionally, the quartile and whisker values from the boxplot are shown inside the violin.
# - The downside is that, because the violinplot uses a KDE, there are some other parameters that may need tweaking, adding some complexity relative to the straightforward boxplot:

# %%
sns.catplot(x="total_bill", y="day", hue="sex",
            kind="violin", bw=.15, cut=0,
            data=tips)

plt.show()

# %% [markdown]
# It’s also possible to “split” the violins when the hue parameter has only two levels, which can allow for a more efficient use of space

# %%
sns.catplot(x="day", y="total_bill", hue="sex",
            kind="violin", split=True, data=tips)

plt.show()

# %% [markdown]
# Finally, there are several options for the plot that is drawn on the interior of the violins, including ways to show each individual observation instead of the summary boxplot values

# %%
sns.catplot(x="day", y="total_bill", hue="sex",
            kind="violin", inner="stick", split=True,
            palette="pastel", data=tips)

plt.show()

# %% [markdown]
# ## 5. Multi-plot grids in Seaborn

# %% [markdown]
# ### 5a) Pairplot

# %% [markdown]
# Plot pairwise relationships in a dataset.
#
# By default, this function will create a grid of Axes such that each numeric variable in data will by shared across the y-axes across a single row and the x-axes across a single column. The diagonal plots are treated differently: a univariate distribution plot is drawn to show the marginal distribution of the data in each column.
#
# It is also possible to show a subset of variables or plot different variables on the rows and columns.
#
# This is a high-level interface for PairGrid that is intended to make it easy to draw a few common styles. You should use PairGrid directly if you need more flexibility.

# %%
penguins = sns.load_dataset("penguins")

penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# The simplest invocation uses scatterplot() for each pairing of the variables and histplot() for the marginal plots along the diagonal

# %%
sns.set_theme(style="ticks")

sns.pairplot(penguins)
plt.show()

# %% [markdown]
# Assigning a hue variable adds a semantic mapping and changes the default marginal plot to a layered kernel density estimate (KDE)

# %%
sns.pairplot(penguins, hue="species")
plt.show()

# %% [markdown]
# We can marginally enforce marginal histogram.

# %%
sns.pairplot(penguins, hue="species", diag_kind="hist")
plt.show()

# %% [markdown]
# ### 5b) JointPlot

# %% [markdown]
# JointPlots - Draw a plot of two variables with bivariate and univariate graphs.

# %%
penguins = sns.load_dataset("penguins")
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")

plt.show()

# %% [markdown]
# Assigning a hue variable will add conditional colors to the scatterplot and draw separate density curves (using kdeplot()) on the marginal axes:

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")

plt.show()

# %% [markdown]
# You can set kind="reg" to add a linear regression fit (using regplot()) and univariate KDE curves:

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", kind="reg")

plt.show()

# %% [markdown]
# ## 6. Matrix plots in Seaborn

# %% [markdown]
# - Heatmaps
# - Clustermaps

# %% [markdown]
# ### 6a) Heatmaps

# %% [markdown]
# Plot rectangular data as a color-encoded matrix.

# %%
# Plotting a heatmap for a numpy array

import numpy as np 
import seaborn as sns

np.random.seed(0)
sns.set_theme()

uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(uniform_data)

# %% [markdown]
# Change the limits of the colormap.

# %%
ax = sns.heatmap(uniform_data, vmin=0, vmax=1)

# %% [markdown]
# You cal also plot a heatmap for data centered on 0 with a diverging colormap:

# %%
normal_data = np.random.randn(10, 12)
ax = sns.heatmap(normal_data, center=0)

# %% [markdown]
# Considering the flights dataset to analyze.

# %%
flights = sns.load_dataset("flights")

flights.sample(4)
# Out:
#      year month  passengers
# 87   1956   Apr         313
# 125  1959   Jun         472
# 92   1956   Sep         355
# 106  1957   Nov         305

# %%
flights = flights.pivot("month", "year", "passengers")
ax = sns.heatmap(flights)

# %%
flights_pivot.head()
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201

# %% [markdown]
# You can annotate each cell with the numeric value using integer formatting:

# %%
ax = sns.heatmap(flights_pivot, annot=True, fmt="d")

# %%
# Slightly neat way of representing cells with some line widths

ax = sns.heatmap(flights_pivot, linewidths=.5)

# %% [markdown]
# ### 6b) Clustermaps

# %% [markdown]
# The clustermap() function of seaborn plots a hierarchically-clustered heat map of the given matrix dataset. It returns a clustered grid index.

# %%
import seaborn as sns
from sunbird.categorical_encoding import frequency_encoding

# %%
flights = sns.load_dataset('flights')

flights.sample(4)
# Out:
#      year month  passengers
# 19   1950   Aug         170
# 22   1950   Nov         114
# 136  1960   May         472
# 83   1955   Dec         278

# %%
# Categorical encoding
frequency_encoding(flights, 'month')

# %%
sns.clustermap(flights, figsize=(7, 7))

# %% [markdown]
# The legend to the left of the cluster map indicates information about the cluster map e.g bright color indicates more passengers and dark color indicates fewer passengers.

# %% [markdown]
# ## 7. Regression plots in Seaborn

# %% [markdown]
# - lmplot : Plot data and regression model fits across a FacetGrid.
# - regplot : Plot data and a linear regression model fit.
# - residplot : Plot the residuals of a linear regression.

# %% [markdown]
# ### 7a) lmplot

# %%
sns.set_theme(color_codes=True)

tips = sns.load_dataset("tips")

tips.sample(4)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 82        10.07  1.83  Female     No  Thur   Lunch     1

# %%
g = sns.lmplot(x="total_bill", y="tip", data=tips)

# %% [markdown]
# You can condition on a third variable and plot the levels in different colors:

# %%
g = sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips)

# %% [markdown]
# ### 7b) regplot, residplot

# %%
sns.regplot(x="total_bill", y="tip", data=tips)

plt.show()

# %% [markdown]
# You can also plot regression with other plots in other context.
#
# For example: jointplot and using ```kind=reg```

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg")

plt.show()

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="resid")

plt.show()

# %% [markdown]
# # Summary
#
# Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures.
#
# Seaborn helps you explore and understand your data. Its plotting functions operate on dataframes and arrays containing whole datasets and internally perform the necessary semantic mapping and statistical aggregation to produce informative plots. Its dataset-oriented, declarative API lets you focus on what the different elements of your plots mean, rather than on the details of how to draw them.
#
# We can use both Matplotlib and Seaborn for data visualization in Python and they are very powerful and pretty much covers all type of purposes. It is important to understand how to pick which chart for what purposes.
